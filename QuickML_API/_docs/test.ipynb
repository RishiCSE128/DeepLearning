# %%
import pandas as pd
import numpy as np

df1 = pd.DataFrame({'A': [0, 1, 2, 3, 4],
                   'B': [5, 6, 7, 8, 9],
                   'C': ['a', 'b', 'c', 'd', 'e']})

df2 = pd.DataFrame({'A1': [0, 1, 2, 3, 4],
                   'A2': [5, 6, 7, 8, 9],
                   'A3': ['a', 'b', 'c', 'd', 'e']})

# %%
df1
# Out:
#    A  B  C
# 0  0  5  a
# 1  1  6  b
# 2  2  7  c
# 3  3  8  d
# 4  4  9  e

# %%
df2
# Out:
#    A1  A2 A3
# 0   0   5  a
# 1   1   6  b
# 2   2   7  c
# 3   3   8  d
# 4   4   9  e

# %%
col_map = {}
idx  = 0
to_replace = ['A']
for col in df.columns:
    col_map[col] = idx
    idx+=1

df1_mat = df1.to_numpy()
df2_mat = df2.to_numpy()

for col in to_replace:
    col_idx = col_map[col]
    df1_mat[: , col_idx] = df2_mat[:] 

df1_mat
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [14], line 13
#      11 for col in to_replace:
#      12     col_idx = col_map[col]
# ---> 13     df1_mat[: , col_idx] = df2_mat[:]
#      15 df1_mat
#
# ValueError: could not broadcast input array from shape (5,3) into shape (5,)

# %%
df1.columns.get_loc('A')
# Out:
# 0

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [21], line 1
# ----> 1 A = np.ndarray([['France', 44.0, 72000.0, 'No'],
#       2 ['Spain', 27.0, 48000.0, 'Yes'],
#       3 ['Germany', 30.0, 54000.0, 'No'],
#       4 ['Spain', 38.0, 61000.0, 'No'],
#       5 ['Germany', 40.0, 63777.77777777778, 'Yes'],
#       6 ['France', 35.0, 58000.0, 'Yes'],
#       7 ['Spain', 38.77777777777778, 52000.0, 'No'],
#       8 ['France', 48.0, 79000.0, 'Yes'],
#       9 ['Germany', 50.0, 83000.0, 'No'],
#      10 ['France', 37.0, 67000.0, 'Yes']])
#      12 B = np.ndarray(
#      13     [[1.0, 0.0, 0.0],
#      14     [0.0, 0.0, 1.0],
#    (...)
#      21     [0.0, 1.0, 0.0],
#      22     [1.0, 0.0, 0.0]])
#
# TypeError: 'list' object cannot be interpreted as an integer

# %%
import pandas as pd
import numpy as np

# %%
bridge_types = ('Arch','Beam','Truss','Cantilever','Tied Arch','Suspension','Cable')
bridge_df = pd.DataFrame(bridge_types, columns=['Bridge_Types'])

# %%
bridge_df
# Out:
#   Bridge_Types
# 0         Arch
# 1         Beam
# 2        Truss
# 3   Cantilever
# 4    Tied Arch
# 5   Suspension
# 6        Cable

# %%
dum_df = pd.get_dummies(bridge_df, columns=["Bridge_Types"], prefix=["Typeo_is"] )

# %%
dum_df
# Out:
#    Typeo_is_Arch  Typeo_is_Beam  Typeo_is_Cable  Typeo_is_Cantilever  \
# 0              1              0               0                    0
# 1              0              1               0                    0
# 2              0              0               0                    0
# 3              0              0               0                    1
# 4              0              0               0                    0
# 5              0              0               0                    0
# 6              0              0               1                    0
#
#    Typeo_is_Suspension  Typeo_is_Tied Arch  Typeo_is_Truss
# 0                    0                   0               0
# 1                    0                   0               0
# 2                    0                   0               1
# 3                    0                   0               0
# 4                    0                   1               0
# 5                    1                   0               0
# ...

# %%
bridge_df = bridge_df.join(dum_df)

# %%
bridge_df
# Out:
#   Bridge_Types  Typeo_is_Arch  Typeo_is_Beam  Typeo_is_Cable  \
# 0         Arch              1              0               0
# 1         Beam              0              1               0
# 2        Truss              0              0               0
# 3   Cantilever              0              0               0
# 4    Tied Arch              0              0               0
# 5   Suspension              0              0               0
# 6        Cable              0              0               1
#
#    Typeo_is_Cantilever  Typeo_is_Suspension  Typeo_is_Tied Arch  \
# 0                    0                    0                   0
# 1                    0                    0                   0
# 2                    0                    0                   0
# 3                    1                    0                   0
# 4                    0                    0                   1
# 5                    0                    1                   0
# ...
